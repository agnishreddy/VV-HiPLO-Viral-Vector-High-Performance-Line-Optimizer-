# %%
get_ipython().system('python "/content/vv_hiplo_optimizer (1).py"')
# Out:
# ✅ All dependencies loaded successfully
# ✅ Module 1: Knowledge Base loaded — 7 promoters, 8 regulatory elements, 8 TFs
# ✅ Module 2: PromoterEngineer class ready
# ✅ Module 3: CodonOptimizer class ready
# ✅ Module 4: HelperPlasmidDesigner class ready
# ✅ Module 5: YieldPredictor class ready
# ✅ Module 6: Visualizer class ready
# ✅ Module 7: ReportGenerator class ready
# ...
#   VV-HiPLO OPTIMIZER v2.0
#   High-Yield Viral Vector Producer Line Sequence Optimizer
# ...
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   STEP 1/7: ENGINEERING HYBRID PROMOTERS
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   Scoring existing promoters:
#     CMV_immediate_early       → Score:   73.2 | GC:  46.1% | TF:  14.4/kb
#     CAG_promoter              → Score:   96.3 | GC:  84.0% | TF:  43.6/kb
#     EF1alpha                  → Score:   14.3 | GC:  94.4% | TF:   0.0/kb
#     SFFV                      → Score:  100.0 | GC:  89.1% | TF:  97.7/kb
# ...

# %%
get_ipython().system('pip install biopython')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 18.4 MB/s eta 0:00:00
# ...
